# %%
import pandas as pd
import seaborn as sb

# %%
df=pd.read_csv('C:/Users/hrashikesh hegde/Downloads/weather_data.csv')
df.set_index('day',inplace=True)

# %%
df
# Out:
#            temperature  windspeed   event
# day
# 1/1/2017          32.0        6.0    Rain
# 1/4/2017           NaN        9.0   Sunny
# 1/5/2017          28.0        NaN    Snow
# 1/6/2017           NaN        7.0     NaN
# 1/7/2017          32.0        NaN    Rain
# 1/8/2017           NaN        NaN   Sunny
# 1/9/2017           NaN        NaN     NaN
# 1/10/2017         34.0        8.0  Cloudy
# 1/11/2017         40.0       12.0   Sunny

# %%
sb.heatmap(df.isnull())

# %%
#filling null values

# %%
new_df=df.fillna(0)

# %%
new_df
# Out:
#            temperature  windspeed   event
# day
# 1/1/2017          32.0        6.0    Rain
# 1/4/2017           0.0        9.0   Sunny
# 1/5/2017          28.0        0.0    Snow
# 1/6/2017           0.0        7.0       0
# 1/7/2017          32.0        0.0    Rain
# 1/8/2017           0.0        0.0   Sunny
# 1/9/2017           0.0        0.0       0
# 1/10/2017         34.0        8.0  Cloudy
# 1/11/2017         40.0       12.0   Sunny

# %%
new_df=df.fillna({
    'temperature':0,
    'windspeed':0,
    
    'event':'no event'
    
    
})

# %%
new_df
# Out:
#            temperature  windspeed     event
# day
# 1/1/2017          32.0        6.0      Rain
# 1/4/2017           0.0        9.0     Sunny
# 1/5/2017          28.0        0.0      Snow
# 1/6/2017           0.0        7.0  no event
# 1/7/2017          32.0        0.0      Rain
# 1/8/2017           0.0        0.0     Sunny
# 1/9/2017           0.0        0.0  no event
# 1/10/2017         34.0        8.0    Cloudy
# 1/11/2017         40.0       12.0     Sunny

# %%
new_df=df.fillna(method="ffill")
new_df
# Out:
#            temperature  windspeed   event
# day
# 1/1/2017          32.0        6.0    Rain
# 1/4/2017          32.0        9.0   Sunny
# 1/5/2017          28.0        9.0    Snow
# 1/6/2017          28.0        7.0    Snow
# 1/7/2017          32.0        7.0    Rain
# 1/8/2017          32.0        7.0   Sunny
# 1/9/2017          32.0        7.0   Sunny
# 1/10/2017         34.0        8.0  Cloudy
# 1/11/2017         40.0       12.0   Sunny

# %%
new_df=df.fillna(method="bfill")
new_df
# Out:
#            temperature  windspeed   event
# day
# 1/1/2017          32.0        6.0    Rain
# 1/4/2017          28.0        9.0   Sunny
# 1/5/2017          28.0        7.0    Snow
# 1/6/2017          32.0        7.0    Rain
# 1/7/2017          32.0        8.0    Rain
# 1/8/2017          34.0        8.0   Sunny
# 1/9/2017          34.0        8.0  Cloudy
# 1/10/2017         34.0        8.0  Cloudy
# 1/11/2017         40.0       12.0   Sunny

# %%
#linear interpolation
#linerar interpolation is a interpolation of curve fitting using linear interpolaton
#to construct new datapoints
#within the range of a discret set of known data poins

new_df=df.interpolate()
new_df
# Out:
#            temperature  windspeed   event
# day
# 1/1/2017     32.000000       6.00    Rain
# 1/4/2017     30.000000       9.00   Sunny
# 1/5/2017     28.000000       8.00    Snow
# 1/6/2017     30.000000       7.00     NaN
# 1/7/2017     32.000000       7.25    Rain
# 1/8/2017     32.666667       7.50   Sunny
# 1/9/2017     33.333333       7.75     NaN
# 1/10/2017    34.000000       8.00  Cloudy
# 1/11/2017    40.000000      12.00   Sunny

# %%
df
# Out:
#            temperature  windspeed   event
# day
# 1/1/2017          32.0        6.0    Rain
# 1/4/2017           NaN        9.0   Sunny
# 1/5/2017          28.0        NaN    Snow
# 1/6/2017           NaN        7.0     NaN
# 1/7/2017          32.0        NaN    Rain
# 1/8/2017           NaN        NaN   Sunny
# 1/9/2017           NaN        NaN     NaN
# 1/10/2017         34.0        8.0  Cloudy
# 1/11/2017         40.0       12.0   Sunny

# %%
new_df=df.dropna()
new_df
# Out:
#            temperature  windspeed   event
# day
# 1/1/2017          32.0        6.0    Rain
# 1/10/2017         34.0        8.0  Cloudy
# 1/11/2017         40.0       12.0   Sunny

# %%
new_df=df.dropna(how='all')
new_df
# Out:
#            temperature  windspeed   event
# day
# 1/1/2017          32.0        6.0    Rain
# 1/4/2017           NaN        9.0   Sunny
# 1/5/2017          28.0        NaN    Snow
# 1/6/2017           NaN        7.0     NaN
# 1/7/2017          32.0        NaN    Rain
# 1/8/2017           NaN        NaN   Sunny
# 1/10/2017         34.0        8.0  Cloudy
# 1/11/2017         40.0       12.0   Sunny

# %%
new_df=df.dropna(thresh=2)
new_df
# Out:
#            temperature  windspeed   event
# day
# 1/1/2017          32.0        6.0    Rain
# 1/4/2017           NaN        9.0   Sunny
# 1/5/2017          28.0        NaN    Snow
# 1/7/2017          32.0        NaN    Rain
# 1/10/2017         34.0        8.0  Cloudy
# 1/11/2017         40.0       12.0   Sunny

# %%
new_df=df.drop('1/4/2017',axis=0)
new_df
# Out:
#            temperature  windspeed   event
# day
# 1/1/2017          32.0        6.0    Rain
# 1/5/2017          28.0        NaN    Snow
# 1/6/2017           NaN        7.0     NaN
# 1/7/2017          32.0        NaN    Rain
# 1/8/2017           NaN        NaN   Sunny
# 1/9/2017           NaN        NaN     NaN
# 1/10/2017         34.0        8.0  Cloudy
# 1/11/2017         40.0       12.0   Sunny

# %%
new_df=df.drop('windspeed',axis=1)
new_df
# Out:
#            temperature   event
# day
# 1/1/2017          32.0    Rain
# 1/4/2017           NaN   Sunny
# 1/5/2017          28.0    Snow
# 1/6/2017           NaN     NaN
# 1/7/2017          32.0    Rain
# 1/8/2017           NaN   Sunny
# 1/9/2017           NaN     NaN
# 1/10/2017         34.0  Cloudy
# 1/11/2017         40.0   Sunny

# %%
new_df=df.drop(["windspeed","event"],axis=1)
new_df
# Out:
#            temperature
# day
# 1/1/2017          32.0
# 1/4/2017           NaN
# 1/5/2017          28.0
# 1/6/2017           NaN
# 1/7/2017          32.0
# 1/8/2017           NaN
# 1/9/2017           NaN
# 1/10/2017         34.0
# 1/11/2017         40.0

# %%
df.drop(["windspeed"],axis=1,inplace=True)

# %%
df
# Out:
#            temperature   event
# day
# 1/1/2017          32.0    Rain
# 1/4/2017           NaN   Sunny
# 1/5/2017          28.0    Snow
# 1/6/2017           NaN     NaN
# 1/7/2017          32.0    Rain
# 1/8/2017           NaN   Sunny
# 1/9/2017           NaN     NaN
# 1/10/2017         34.0  Cloudy
# 1/11/2017         40.0   Sunny
